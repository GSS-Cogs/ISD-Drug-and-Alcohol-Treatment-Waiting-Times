# %% [markdown]
# Table 2 - Distribution of Completed Waits by Age Group (years) and Gender, Alcohol and Drugs, year ending 31st March 2018

# %% [markdown]
# Percentage of non-anonymous clients who have started first treatment within 3 weeks

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('http://www.isdscotland.org/Health-Topics/Drugs-and-Alcohol-Misuse/Publications/')
    scraper.select_dataset(title='National Drug and Alcohol Treatment Waiting Times')
    tabs = scraper.distribution(title='April 2014 - March 2018 Demographic Tables').as_databaker()
    tab = next(t for t in tabs if t.name == '3wk performance data')
# Out:
# WARNING:Broken link to dataset data-tables2017.asp?id=1894#1894
# WARNING:Broken link to dataset data-tables2017.asp?id=1887#1887
# WARNING:Broken link to dataset data-tables.asp?id=1508#1508
# WARNING:Broken link to dataset data-tables.asp?id=1386#1386
# WARNING:Broken link to dataset data-tables.asp?id=1318#1318
# WARNING:Broken link to dataset data-tables.asp?id=1318#1318
# WARNING:Broken link to dataset data-tables.asp?id=1238#1238
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735

# %% [markdown]
# https://www.isdscotland.org/Health-Topics/Drugs-and-Alcohol-Misuse/Publications/2018-09-25/April-2014-March-2018-DATWT-Demographic-Tables.xlsx

# %%
observations = tab.excel_ref('B2').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<C2090 100.0>, <B1160 100.0>, <B657 95.22900763358778>, <F1374 94.03183023872678>, <E340 85.18518518518519>, <C2102 100.0>, <D1122 100.0>, <C1707 88.88888888888889>, <E92 94.11764705882352>, <C1350 100.0>, <B808 100.0>, <E1551 98.71794871794873>, <F1443 99.19028340080972>, <D991 100.0>, <F1194 98.21428571428571>, <E9 98.81656804733728>, <E1447 86.66666666666667>, <D858 70.22222222222221>, <C625 100.0>, <F373 96.75324675324676>, <C752 96.58119658119658>, <F912 100.0>, <C436 93.33333333333333>, <F1165 100.0>, <E46 100.0>, <F1591 94.01294498381877>, <F1492 99.29328621908127>, <D1691 100.0>, <D184 75.0>, <F1361 90.0>, <F1479 94.84118746107536>, <E2069 100.0>, <C391 94.0>, <B828 95.55555555555556>, <E2147 97.19254658385094>, <C1303 90.2439024390244>, <C1474 95.33169533169533>, <F121 83.82775119617224>, <B1602 81.98757763975155>, <C1329 87.05035971223022>, <E1380 80.0>, <F1729 98.32635983263597>, <B218 90.9090909090909>, <C1121 96.875>, <B1702 100.0>, <C654 55.55555555555556>, <C2230 92.73411205701841>, <B188 100.0>, <D250 66.66666666666666>, <F1452 89.43089430894308>, <D952 100.0>, <C1864 96.90721649484536>, <E1737 100.0>, <F618 100.0>, <D1468 93.50691096110575>, <C1399 96.47887323943662>, <F377 96.1038961038961>, <C293 96.50949173300674>, <B2123 92.97752808988764>, <F1868 98.14410480349345>, <D549 97.01492537313433>, <F2095 100.0>, <F547 95.7850368809273>, <E1051 94.28571428571428>, <B1213 99
>, <A535 '206d12M'>, <A743 'd21M'>, <A1793 '126b21'>, <A2127 '214d41'>, <A1599 '110b11'>, <A606 '212b41M'>, <A415 '133d12M'>, <A1725 '121d41'>, <A1755 '123d41'>, <A1534 '104a11'>, <A1632 '114b31'>, <A342 '128d31M'>, <A1340 '211d31F'>, <A993 '122d12F'>, <A1310 '209d31F'>, <A1950 '200d41'>, <A468 '202a41M'>, <A1286 '207a41F'>, <A403 '132d41M'>, <A361 '130a21M'>, <A2039 '207d31'>, <A2228 'd11'>, <A1691 '119d11'>, <A792 '104a21F'>, <A805 '106a11F'>, <A2128 '215a11'>, <A24 '102b21M'>, <A808 '106a31F'>, <A2040 '207d41'>, <A785 '103b41F'>, <A753 '101b21F'>, <A1031 '125a41F'>, <A2182 '290b41'>, <A1220 '202d31F'>, <A709 '412b31M'>, <A1028 '125a12F'>, <A597 '211d31M'>, <A68 '106b12M'>, <A34 '103a21M'>, <A158 '115b12M'>, <A1404 '218b11F'>, <A1689 '119b31'>, <A1697 '120a12'>, <A1056 '126d41F'>, <A1843 '129d21'>, <A1313 '210a12F'>, <A1810 '127b41'>, <A689 '290a31M'>, <A1169 '134b21F'>, <A2143 '218a11'>, <A653 '215d21M'>, <A542 '207a31M'>, <A958 '120b12F'>, <A1840 '129b41'>, <A552 '207d31M'>, <A1569 '107b11'>, <A594 '211d11M'>, <A19 '102a21M'>, <A1283 '207a12F'>, <A1880 '132a41'>, <A1321 '210b41F'>, <A1353 '212d41F'>, <A1407 '218b31F'>, <A1657 '117a31'>, <A2061 '210b11'>, <A118 '110d12M'>, <A1742 '123a12'>, <A1038 '125d12F'>, <A1628 '114a41'>, <A115 '110b31M'>, <A1110 '130b31F'>, <A1643 '115a41'>, <A2087 '212a21'>, <A2082 '211d12'>, <A298 '125d41M'>, <A562 '209b31M'>, <A396 '132b21M'>, <A576 '210b21M'>, <A850 '110a11F'>, <A1763 '124b21'>, <A978 '121d ...

# %%
Age = tab.excel_ref('B1').expand(RIGHT).is_not_blank()
Age
# Out:
# {<F1 'pc_u3wks'>, <E1 'AGOver_50'>, <B1 'AG0_29'>, <C1 'AG30_39'>, <D1 'AG40_49'>}

# %%
Dimensions = [
            HDim(des,'des',DIRECTLY,LEFT),
            HDim(Age,'Age',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Percentage'),
            HDimConst('Unit','non-anon-clients'),
            HDimConst('Status','Percentage of non-anonymous clients who have started first treatment within 3 weeks')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#               OBS      des        Age Measure Type    Unit  \
# 0      100.000000  101a11M     AG0_29   Percentage  People
# 1      100.000000  101a11M    AG30_39   Percentage  People
# 2       99.390244  101a11M    AG40_49   Percentage  People
# 3       98.901099  101a11M  AGOver_50   Percentage  People
# 4       99.480069  101a11M   pc_u3wks   Percentage  People
# 5      100.000000  101a12M     AG0_29   Percentage  People
# 6       98.765432  101a12M    AG30_39   Percentage  People
# 7      100.000000  101a12M    AG40_49   Percentage  People
# 8       99.324324  101a12M  AGOver_50   Percentage  People
# 9       99.487179  101a12M   pc_u3wks   Percentage  People
# 10     100.000000  101a21M     AG0_29   Percentage  People
# 11     Percentage of non-anonymous clients who have s...
# 12     Percentage of non-anonymous clients who have s...
# 13     Percentage of non-anonymous clients who have s...
# 14     Percentage of non-anonymous clients who have s...
# 15     Percentage of non-anonymous clients who have s...
# 16     Percentage of non-anonymous clients who have s...
# 17     Percentage of non-anonymous clients who have s...
# 18     Percentage of non-anonymous clients who have s...
# 19     Percentage of non-anonymous clients who have s...
# 20     Percentage of non-anonymous clients who have s...
# 21     Percentage of non-anonymous clients who have s...
# 22     Percentage of non-anonymous clients who have s...
# 23     Percentage of non-anonymous clients who have s...
# 24     Percentage of non-anonymous clients who have s...
# 25     Percentage of non-anonymous clients who have s...
# 26     Percentage of non-anonymous clients who have s...
# 27     Percentage of non-anonymous clients who have s...
# 28     Percentage of non-anonymous clients who have s...
# 29     Percentage of non-anonymous clients who have s...
# ...                                                  ...
# 11000  Percentage of non-anonymous clients who have s...
# 11001  Percentage of non-anonymous clients who have s...
# 11002  Percentage of non-anonymous clients who have s...
# 11003  Percentage of non-anonymous clients who have s...
# 11004  Percentage of non-anonymous clients who have s...
# 11005  Percentage of non-anonymous clients who have s...
# 11006  Percentage of non-anonymous clients who have s...
# 11007  Percentage of non-anonymous clients who have s...
# 11008  Percentage of non-anonymous clients who have s...
# 11009  Percentage of non-anonymous clients who have s...
# 11010  Percentage of non-anonymous clients who have s...
# 11011  Percentage of non-anonymous clients who have s...
# 11012  Percentage of non-anonymous clients who have s...
# 11013  Percentage of non-anonymous clients who have s...
# 11014  Percentage of non-anonymous clients who have s...
# 11015  Percentage of non-anonymous clients who have s...
# 11016  Percentage of non-anonymous clients who have s...
# 11017  Percentage of non-anonymous clients who have s...
# 11018  Percentage of non-anonymous clients who have s...
# 11019  Percentage of non-anonymous clients who have s...
# 11020  Percentage of non-anonymous clients who have s...
# 11021  Percentage of non-anonymous clients who have s...
# 11022  Percentage of non-anonymous clients who have s...
# 11023  Percentage of non-anonymous clients who have s...
# 11024  Percentage of non-anonymous clients who have s...
# 11025  Percentage of non-anonymous clients who have s...
# 11026  Percentage of non-anonymous clients who have s...
# 11027  Percentage of non-anonymous clients who have s...
# 11028  Percentage of non-anonymous clients who have s...
# 11029  Percentage of non-anonymous clients who have s...
#
# [11030 rows x 6 columns]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce').fillna(0)

# %%
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('pc_u3wks', 'AGAll'))

# %%
# new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.head()
# Out:
#         Value      des        Age Measure Type    Unit  \
# 0  100.000000  101a11M     AG0_29   Percentage  People
# 1  100.000000  101a11M    AG30_39   Percentage  People
# 2   99.390244  101a11M    AG40_49   Percentage  People
# 3   98.901099  101a11M  AGOver_50   Percentage  People
# 4   99.480069  101a11M      AGAll   Percentage  People
#
#                                               Status
# 0  Percentage of non-anonymous clients who have s...
# 1  Percentage of non-anonymous clients who have s...
# 2  Percentage of non-anonymous clients who have s...
# 3  Percentage of non-anonymous clients who have s...
# 4  Percentage of non-anonymous clients who have s...

# %%
new_table = new_table[new_table['Value'] != 0 ]

# %%
new_table.dtypes
# Out:
# Value           float64
# des              object
# Age              object
# Measure Type     object
# Unit             object
# Status           object
# dtype: object

# %%
new_table.head(3)
# Out:
#         Value      des      Age Measure Type    Unit  \
# 0  100.000000  101a11M   AG0_29   Percentage  People
# 1  100.000000  101a11M  AG30_39   Percentage  People
# 2   99.390244  101a11M  AG40_49   Percentage  People
#
#                                               Status
# 0  Percentage of non-anonymous clients who have s...
# 1  Percentage of non-anonymous clients who have s...
# 2  Percentage of non-anonymous clients who have s...

# %%
new_table['Trust'] = new_table['des'].astype(str).str[0:3]
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Trust'].unique()
# Out:
# array(['101', '102', '103', '104', '106', '107', '108', '110', '111',
#        '114', '115', '117', '118', '119', '120', '121', '122', '123',
#        '124', '125', '126', '127', '128', '129', '130', '131', '132',
#        '133', '134', '135', '200', '202', '203', '204', '205', '206',
#        '207', '209', '210', '211', '212', '213', '214', '215', '218',
#        '230', '290', '412', '999', 'a11', 'a12', 'a21', 'a31', 'a41',
#        'b11', 'b12', 'b21', 'b31', 'b41', 'd11', 'd12', 'd21', 'd31',
#        'd41'], dtype=object)

# %%
new_table['Client'] = new_table['des'].astype(str).str[3:4]
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Client'].unique()
# Out:
# array(['a', 'b', 'd', 'M', 'F', ''], dtype=object)

# %%
new_table['Period'] = new_table['des'].astype(str).str[4:6]
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Period'].unique()
# Out:
# array(['11', '12', '21', '31', '41', ''], dtype=object)

# %%
new_table['Sex'] = new_table['des'].astype(str).str[6:]
# Out:
# /home/alex/.virtualenvs/databaker/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Sex'].unique()
# Out:
# array(['M', '', 'F'], dtype=object)

# %%
new_table = new_table[new_table['Sex'] != '' ]

# %%
new_table['Client'] = new_table['Client'].map(
    lambda x: {
        'a' : 'Alcohol', 
        'b' : 'Alcohol and Drugs',
        'd' : 'Drugs'
        }.get(x, x))

# %%
new_table['Period'] = new_table['Period'].map(
    lambda x: {
        '11' : '31st March 2014', 
        '21' : '31st March 2015',
        '31' : '31st March 2016',
        '41' : '31st March 2017',
        '12' :  '31st March 2018'
        }.get(x, x))

# %%
new_table['Trust'].unique()
# Out:
# array(['101', '102', '103', '104', '106', '107', '108', '110', '111',
#        '114', '115', '117', '118', '119', '120', '121', '122', '123',
#        '124', '125', '126', '127', '128', '129', '130', '131', '132',
#        '133', '134', '135', '200', '202', '203', '204', '205', '206',
#        '207', '209', '210', '211', '212', '213', '214', '215', '218',
#        '230', '290', '412', '999'], dtype=object)

# %%
new_table.head(1)
# Out:
#    Value      des     Age Measure Type    Unit  \
# 0  100.0  101a11M  AG0_29   Percentage  People
#
#                                               Status Trust   Client  \
# 0  Percentage of non-anonymous clients who have s...   101  Alcohol
#
#             Period Sex
# 0  31st March 2014   M

# %%
new_table = new_table[['Period','Age','Sex','Trust','Client','Status','Measure Type','Value','Unit']]

# %%
if is_interactive():
    from pathlib import Path
    destinationFolder = Path('out')
    destinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(destinationFolder / ('table2.csv'), index = False)
