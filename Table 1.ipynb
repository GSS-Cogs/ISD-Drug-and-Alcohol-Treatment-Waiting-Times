# %% [markdown]
# Completed waits by age and gender table compiled from hidden tables Non Anon Totals

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('http://www.isdscotland.org/Health-Topics/Drugs-and-Alcohol-Misuse/Publications/')
    scraper.select_dataset(title='National Drug and Alcohol Treatment Waiting Times')
    tabs = scraper.distribution(title='April 2014 - March 2018 Demographic Tables').as_databaker()
    tab = next(t for t in tabs if t.name == 'Non Anon Totals')
# Out:
# WARNING:Broken link to dataset data-tables2017.asp?id=2370#2370
# WARNING:Broken link to dataset data-tables2017.asp?id=1894#1894
# WARNING:Broken link to dataset data-tables2017.asp?id=1887#1887
# WARNING:Broken link to dataset data-tables.asp?id=1508#1508
# WARNING:Broken link to dataset data-tables.asp?id=1386#1386
# WARNING:Broken link to dataset data-tables.asp?id=1318#1318
# WARNING:Broken link to dataset data-tables.asp?id=1238#1238
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735
# WARNING:Broken link to dataset data-tables.asp?id=735#735

# %%
observations = tab.excel_ref('B2').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<C1187 109.0>, <C1065 94.0>, <D940 '*'>, <B1324 71.0>, <E499 44.0>, <F75 11.0>, <F510 116.0>, <D477 37.0>, <E2103 1819.0>, <E879 92.0>, <C948 66.0>, <E867 57.0>, <D1244 103.0>, <B733 16.0>, <C1741 328.0>, <E1028 89.0>, <F1783 1140.0>, <B581 29.0>, <B1147 48.0>, <B1864 161.0>, <E1544 29.0>, <C1814 332.0>, <C2078 1956.0>, <C1864 339.0>, <B1158 107.0>, <F1224 382.0>, <E1559 40.0>, <F1440 560.0>, <C455 13.0>, <F693 163.0>, <D416 15.0>, <B251 15.0>, <E2199 6745.0>, <F351 77.0>, <C811 46.0>, <D233 17.0>, <C2121 1657.0>, <C354 28.0>, <E412 37.0>, <E2111 2131.0>, <D2124 1915.0>, <C1123 151.0>, <D1967 823.0>, <E1080 56.0>, <E1739 46.0>, <D674 40.0>, <C1302 120.0>, <B2026 383.0>, <F1265 409.0>, <B1821 225.0>, <B1135 87.0>, <E2216 9200.0>, <C942 100.0>, <B1096 30.0>, <C679 37.0>, <D116 '*'>, <C376 21.0>, <B1635 68.0>, <C1567 319.0>, <D943 52.0>, <B880 60.0>, <C1788 515.0>, <E2157 986.0>, <C1800 291.0>, <E1130 22.0>, <F1202 363.0>, <C833 52.0>, <F1536 686.0>, <B840 23.0>, <E2203 6781.0>, <E1496 276.0>, <C1713 303.0>, <F740 180.0>, <D1982 556.0>, <D1285 78.0>, <B239 11.0>, <B1599 182.0>, <F746 183.0>, <D1690 199.0>, <E1961 746.0>, <F2036 3229.0>, <C78 '*'>, <D1266 106.0>, <F148 24.0>, <C221 5.0>, <E1650 102.0>, <F385 86.0>, <D1413 122.0>, <F925 240.0>, <B196 '*'>, <C1425 82.0>, <E1946 746.0>, <C496 44.0>, <B1966 327.0>, <C93 '*'>, <F948
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#          OBS DATAMARKER      des        Age Measure Type              Unit  \
# 0                     *  104a11M    AG30_39        Count  non-anon-clients
# 1                     *  104a11M      Total        Count  non-anon-clients
# 2                     *  104a11T    AG30_39        Count  non-anon-clients
# 3                     *  104a11T      Total        Count  non-anon-clients
# 4                     *  104b11F     AG0_29        Count  non-anon-clients
# 5                     *  104b11F    AG40_49        Count  non-anon-clients
# 6                     *  104b11F      Total        Count  non-anon-clients
# 7                     *  104d11F     AG0_29        Count  non-anon-clients
# 8                     *  104d11F    AG40_49        Count  non-anon-clients
# 9                     *  104d11F      Total        Count  non-anon-clients
# 10                    *  120d41F     AG0_29        Count  non-anon-clients
# 11                    *  120d41F      Total        Count  non-anon-clients
# 12                    *  213d41F     AG0_29        Count  non-anon-clients
# 13                    *  213d41F      Total        Count  non-anon-clients
# 14                    *  118d21M     AG0_29        Count  non-anon-clients
# 15                    *  118d21M  AGOver_50        Count  non-anon-clients
# 16                    *  118d21M      Total        Count  non-anon-clients
# 17                    *  212d21M     AG0_29        Count  non-anon-clients
# 18                    *  212d21M  AGOver_50        Count  non-anon-clients
# 19                    *  212d21M      Total        Count  non-anon-clients
# 20                    *  118d21F     AG0_29        Count  non-anon-clients
# 21                    *  118d21F    AG40_49        Count  non-anon-clients
# 22                    *  118d21F      Total        Count  non-anon-clients
# 23                    *  212d21F     AG0_29        Count  non-anon-clients
# 24                    *  212d21F    AG40_49        Count  non-anon-clients
# 25                    *  212d21F      Total        Count  non-anon-clients
# 26                    *  104d11M    AG30_39        Count  non-anon-clients
# 27                    *  104d11M    AG40_49        Count  non-anon-clients
# 28                    *  104d11M      Total        Count  non-anon-clients
# 29                    *  120d31F     AG0_29        Count  non-anon-clients
# ...      ...        ...      ...        ...          ...               ...
# 11000   5234        NaN     b31T     AG0_29        Count  non-anon-clients
# 11001   8704        NaN     b31T    AG30_39        Count  non-anon-clients
# 11002   8331        NaN     b31T    AG40_49        Count  non-anon-clients
# 11003   8293        NaN     b31T  AGOver_50        Count  non-anon-clients
# 11004  30562        NaN     b31T      Total        Count  non-anon-clients
# 11005   6855        NaN  999b11T     AG0_29        Count  non-anon-clients
# 11006  10705        NaN  999b11T    AG30_39        Count  non-anon-clients
# 11007  10268        NaN  999b11T    AG40_49        Count  non-anon-clients
# 11008   9932        NaN  999b11T  AGOver_50        Count  non-anon-clients
# 11009  37760        NaN  999b11T      Total        Count  non-anon-clients
# 11010   6008        NaN  999b12T     AG0_29        Count  non-anon-clients
# 11011  10454        NaN  999b12T    AG30_39        Count  non-anon-clients
# 11012  10486        NaN  999b12T    AG40_49        Count  non-anon-clients
# 11013  10924        NaN  999b12T  AGOver_50        Count  non-anon-clients
# 11014  37872        NaN  999b12T      Total        Count  non-anon-clients
# 11015   6012        NaN  999b41T     AG0_29        Count  non-anon-clients
# 11016  10653        NaN  999b41T    AG30_39        Count  non-anon-clients
# 11017  10324        NaN  999b41T    AG40_49        Count  non-anon-clients
# 11018  11260        NaN  999b41T  AGOver_50        Count  non-anon-clients
# 11019  38249        NaN  999b41T      Total        Count  non-anon-clients
# 11020   6586        NaN  999b31T     AG0_29        Count  non-anon-clients
# 11021  10752        NaN  999b31T    AG30_39        Count  non-anon-clients
# 11022  10650        NaN  999b31T    AG40_49        Count  non-anon-clients
# 11023  10853        NaN  999b31T  AGOver_50        Count  non-anon-clients
# 11024  38841        NaN  999b31T      Total        Count  non-anon-clients
# 11025   6825        NaN  999b21T     AG0_29        Count  non-anon-clients
# 11026  10757        NaN  999b21T    AG30_39        Count  non-anon-clients
# 11027  10755        NaN  999b21T    AG40_49        Count  non-anon-clients
# 11028  10704        NaN  999b21T  AGOver_50        Count  non-anon-clients
# 11029  39041        NaN  999b21T      Total        Count  non-anon-clients
#
#                                                   Status
# 0      Number of non-anonymous clients who have start...
# 1      Number of non-anonymous clients who have start...
# 2      Number of non-anonymous clients who have start...
# 3      Number of non-anonymous clients who have start...
# 4      Number of non-anonymous clients who have start...
# 5      Number of non-anonymous clients who have start...
# 6      Number of non-anonymous clients who have start...
# 7      Number of non-anonymous clients who have start...
# 8      Number of non-anonymous clients who have start...
# 9      Number of non-anonymous clients who have start...
# 10     Number of non-anonymous clients who have start...
# 11     Number of non-anonymous clients who have start...
# 12     Number of non-anonymous clients who have start...
# 13     Number of non-anonymous clients who have start...
# 14     Number of non-anonymous clients who have start...
# 15     Number of non-anonymous clients who have start...
# 16     Number of non-anonymous clients who have start...
# 17     Number of non-anonymous clients who have start...
# 18     Number of non-anonymous clients who have start...
# 19     Number of non-anonymous clients who have start...
# 20     Number of non-anonymous clients who have start...
# 21     Number of non-anonymous clients who have start...
# 22     Number of non-anonymous clients who have start...
# 23     Number of non-anonymous clients who have start...
# 24     Number of non-anonymous clients who have start...
# 25     Number of non-anonymous clients who have start...
# 26     Number of non-anonymous clients who have start...
# 27     Number of non-anonymous clients who have start...
# 28     Number of non-anonymous clients who have start...
# 29     Number of non-anonymous clients who have start...
# ...                                                  ...
# 11000  Number of non-anonymous clients who have start...
# 11001  Number of non-anonymous clients who have start...
# 11002  Number of non-anonymous clients who have start...
# 11003  Number of non-anonymous clients who have start...
# 11004  Number of non-anonymous clients who have start...
# 11005  Number of non-anonymous clients who have start...
# 11006  Number of non-anonymous clients who have start...
# 11007  Number of non-anonymous clients who have start...
# 11008  Number of non-anonymous clients who have start...
# 11009  Number of non-anonymous clients who have start...
# 11010  Number of non-anonymous clients who have start...
# 11011  Number of non-anonymous clients who have start...
# 11012  Number of non-anonymous clients who have start...
# 11013  Number of non-anonymous clients who have start...
# 11014  Number of non-anonymous clients who have start...
# 11015  Number of non-anonymous clients who have start...
# 11016  Number of non-anonymous clients who have start...
# 11017  Number of non-anonymous clients who have start...
# 11018  Number of non-anonymous clients who have start...
# 11019  Number of non-anonymous clients who have start...
# 11020  Number of non-anonymous clients who have start...
# 11021  Number of non-anonymous clients who have start...
# 11022  Number of non-anonymous clients who have start...
# 11023  Number of non-anonymous clients who have start...
# 11024  Number of non-anonymous clients who have start...
# 11025  Number of non-anonymous clients who have start...
# 11026  Number of non-anonymous clients who have start...
# 11027  Number of non-anonymous clients who have start...
# 11028  Number of non-anonymous clients who have start...
# 11029  Number of non-anonymous clients who have start...
#
# [11030 rows x 7 columns]

# %%
new_table = new_table[new_table['OBS'] != '*' ]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Value'] = pd.to_numeric(new_table['Value'], errors='coerce').fillna(0)

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['Age'] = new_table['Age'].map(lambda cell:cell.replace('Total', 'AGALL'))

# %%
new_table.head()
# Out:
#    Value DATAMARKER      des      Age Measure Type              Unit  \
# 0      0          *  104a11M  AG30_39        Count  non-anon-clients
# 1      0          *  104a11M    AGALL        Count  non-anon-clients
# 2      0          *  104a11T  AG30_39        Count  non-anon-clients
# 3      0          *  104a11T    AGALL        Count  non-anon-clients
# 4      0          *  104b11F   AG0_29        Count  non-anon-clients
#
#                                               Status
# 0  Number of non-anonymous clients who have start...
# 1  Number of non-anonymous clients who have start...
# 2  Number of non-anonymous clients who have start...
# 3  Number of non-anonymous clients who have start...
# 4  Number of non-anonymous clients who have start...

# %%
new_table = new_table[new_table['Value'] != 0 ]

# %%
new_table.dtypes
# Out:
# Value            int32
# DATAMARKER      object
# des             object
# Age             object
# Measure Type    object
# Unit            object
# Status          object
# dtype: object

# %%
new_table.head(3)
# Out:
#     Value DATAMARKER      des    Age Measure Type              Unit  \
# 61      5        NaN  122d11F  AGALL        Count  non-anon-clients
# 65      5        NaN  215d11F  AGALL        Count  non-anon-clients
# 73      5        NaN  212d31F  AGALL        Count  non-anon-clients
#
#                                                Status
# 61  Number of non-anonymous clients who have start...
# 65  Number of non-anonymous clients who have start...
# 73  Number of non-anonymous clients who have start...

# %%
new_table['Trust'] = new_table['des'].astype(str).str[0:3]

# %%
new_table['Trust'].unique()
# Out:
# array(['122', '215', '212', '104', '213', '118', '120', '124', '103',
#        '123', '135', '117', '412', '114', '209', '106', '203', '200',
#        '126', '134', '128', '119', '127', '132', '130', '102', '133',
#        '129', '131', '107', '204', '108', '101', '121', '111', '205',
#        '290', '206', '214', '230', '110', '207', '202', '115', '210',
#        '211', '125', '218', 'd11', 'd21', 'd41', 'd12', 'd31', '999',
#        'a12', 'a41', 'a21', 'a31', 'a11', 'b12', 'b21', 'b41', 'b11',
#        'b31'], dtype=object)

# %%
new_table['Client'] = new_table['des'].astype(str).str[3:4]

# %%
new_table['Client'].unique()
# Out:
# array(['d', 'a', 'b', 'F', 'M', 'T'], dtype=object)

# %%
new_table['Period'] = new_table['des'].astype(str).str[4:6]

# %%
new_table['Period'].unique()
# Out:
# array(['11', '31', '21', '41', '12', ''], dtype=object)

# %%
new_table['Sex'] = new_table['des'].astype(str).str[6:]

# %%
new_table['Sex'].unique()
# Out:
# array(['F', 'T', 'M', ''], dtype=object)

# %%
new_table = new_table[new_table['Sex'] != '' ]

# %%
new_table['Client'] = new_table['Client'].map(
    lambda x: {
        'a' : 'Alcohol', 
        'b' : 'Alcohol and Drugs',
        'd' : 'Drugs'
        }.get(x, x))

# %%
new_table['Period'] = new_table['Period'].map(
    lambda x: {
        '11' : '31st March 2014', 
        '21' : '31st March 2015',
        '31' : '31st March 2016',
        '41' : '31st March 2017',
        '12' :  '31st March 2018'
        }.get(x, x))

# %%
new_table['Trust'].unique()
# Out:
# array(['122', '215', '212', '104', '213', '118', '120', '124', '103',
#        '123', '135', '117', '412', '114', '209', '106', '203', '200',
#        '126', '134', '128', '119', '127', '132', '130', '102', '133',
#        '129', '131', '107', '204', '108', '101', '121', '111', '205',
#        '290', '206', '214', '230', '110', '207', '202', '115', '210',
#        '211', '125', '218', '999'], dtype=object)

# %%
new_table.head(1)
# Out:
#     Value DATAMARKER      des    Age Measure Type              Unit  \
# 61      5        NaN  122d11F  AGALL        Count  non-anon-clients
#
#                                                Status Trust Client  \
# 61  Number of non-anonymous clients who have start...   122  Drugs
#
#              Period Sex
# 61  31st March 2014   F

# %%
new_table = new_table[['Period','Age','Sex','Trust','Client','Status','Measure Type','Value','Unit']]

# %%
if is_interactive():
    from pathlib import Path
    destinationFolder = Path('out')
    destinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(destinationFolder / ('table1.csv'), index = False)

# %%
new_table
# Out:
#                 Period        Age Sex Trust             Client  \
# 61     31st March 2014      AGALL   F   122              Drugs
# 65     31st March 2014      AGALL   F   215              Drugs
# 73     31st March 2016      AGALL   F   212              Drugs
# 77     31st March 2014      AGALL   T   104              Drugs
# 80     31st March 2015      AGALL   F   122              Drugs
# 83     31st March 2015      AGALL   F   215              Drugs
# 89     31st March 2016      AGALL   F   122              Drugs
# 92     31st March 2016      AGALL   M   213              Drugs
# 95     31st March 2016      AGALL   F   215              Drugs
# 99     31st March 2015      AGALL   T   118              Drugs
# 103    31st March 2015      AGALL   T   212              Drugs
# 113    31st March 2017      AGALL   F   212            Alcohol
# 121    31st March 2015      AGALL   F   212            Alcohol
# 129    31st March 2016      AGALL   M   213            Alcohol
# 133    31st March 2018      AGALL   F   118              Drugs
# 137    31st March 2018      AGALL   F   212              Drugs
# 145    31st March 2015      AGALL   F   213            Alcohol
# 149    31st March 2014      AGALL   T   104  Alcohol and Drugs
# 152    31st March 2014      AGALL   F   120              Drugs
# 155    31st March 2014      AGALL   F   213              Drugs
# 163    31st March 2016      AGALL   F   212            Alcohol
# 173    31st March 2016      AGALL   F   213            Alcohol
# 177    31st March 2017      AGALL   F   122              Drugs
# 181    31st March 2017      AGALL   F   215              Drugs
# 185    31st March 2017     AG0_29   M   212              Drugs
# 187    31st March 2017      AGALL   M   212              Drugs
# 191    31st March 2016      AGALL   T   120              Drugs
# 195    31st March 2016      AGALL   T   213              Drugs
# 200    31st March 2017      AGALL   F   118  Alcohol and Drugs
# 205    31st March 2017      AGALL   F   212  Alcohol and Drugs
# ...                ...        ...  ..   ...                ...
# 10975  31st March 2015     AG0_29   M   999  Alcohol and Drugs
# 10976  31st March 2015    AG30_39   M   999  Alcohol and Drugs
# 10977  31st March 2015    AG40_49   M   999  Alcohol and Drugs
# 10978  31st March 2015  AGOver_50   M   999  Alcohol and Drugs
# 10979  31st March 2015      AGALL   M   999  Alcohol and Drugs
# 11005  31st March 2014     AG0_29   T   999  Alcohol and Drugs
# 11006  31st March 2014    AG30_39   T   999  Alcohol and Drugs
# 11007  31st March 2014    AG40_49   T   999  Alcohol and Drugs
# 11008  31st March 2014  AGOver_50   T   999  Alcohol and Drugs
# 11009  31st March 2014      AGALL   T   999  Alcohol and Drugs
# 11010  31st March 2018     AG0_29   T   999  Alcohol and Drugs
# 11011  31st March 2018    AG30_39   T   999  Alcohol and Drugs
# 11012  31st March 2018    AG40_49   T   999  Alcohol and Drugs
# 11013  31st March 2018  AGOver_50   T   999  Alcohol and Drugs
# 11014  31st March 2018      AGALL   T   999  Alcohol and Drugs
# 11015  31st March 2017     AG0_29   T   999  Alcohol and Drugs
# 11016  31st March 2017    AG30_39   T   999  Alcohol and Drugs
# 11017  31st March 2017    AG40_49   T   999  Alcohol and Drugs
# 11018  31st March 2017  AGOver_50   T   999  Alcohol and Drugs
# 11019  31st March 2017      AGALL   T   999  Alcohol and Drugs
# 11020  31st March 2016     AG0_29   T   999  Alcohol and Drugs
# 11021  31st March 2016    AG30_39   T   999  Alcohol and Drugs
# 11022  31st March 2016    AG40_49   T   999  Alcohol and Drugs
# 11023  31st March 2016  AGOver_50   T   999  Alcohol and Drugs
# 11024  31st March 2016      AGALL   T   999  Alcohol and Drugs
# 11025  31st March 2015     AG0_29   T   999  Alcohol and Drugs
# 11026  31st March 2015    AG30_39   T   999  Alcohol and Drugs
# 11027  31st March 2015    AG40_49   T   999  Alcohol and Drugs
# 11028  31st March 2015  AGOver_50   T   999  Alcohol and Drugs
# 11029  31st March 2015      AGALL   T   999  Alcohol and Drugs
#
#                                                   Status Measure Type  Value  \
# 61     Number of non-anonymous clients who have start...        Count      5
# 65     Number of non-anonymous clients who have start...        Count      5
# 73     Number of non-anonymous clients who have start...        Count      5
# 77     Number of non-anonymous clients who have start...        Count      5
# 80     Number of non-anonymous clients who have start...        Count      5
# 83     Number of non-anonymous clients who have start...        Count      5
# 89     Number of non-anonymous clients who have start...        Count      5
# 92     Number of non-anonymous clients who have start...        Count      5
# 95     Number of non-anonymous clients who have start...        Count      5
# 99     Number of non-anonymous clients who have start...        Count      6
# 103    Number of non-anonymous clients who have start...        Count      6
# 113    Number of non-anonymous clients who have start...        Count      6
# 121    Number of non-anonymous clients who have start...        Count      6
# 129    Number of non-anonymous clients who have start...        Count      6
# 133    Number of non-anonymous clients who have start...        Count      6
# 137    Number of non-anonymous clients who have start...        Count      6
# 145    Number of non-anonymous clients who have start...        Count      6
# 149    Number of non-anonymous clients who have start...        Count      6
# 152    Number of non-anonymous clients who have start...        Count      6
# 155    Number of non-anonymous clients who have start...        Count      6
# 163    Number of non-anonymous clients who have start...        Count      7
# 173    Number of non-anonymous clients who have start...        Count      7
# 177    Number of non-anonymous clients who have start...        Count      7
# 181    Number of non-anonymous clients who have start...        Count      7
# 185    Number of non-anonymous clients who have start...        Count      6
# 187    Number of non-anonymous clients who have start...        Count      7
# 191    Number of non-anonymous clients who have start...        Count      8
# 195    Number of non-anonymous clients who have start...        Count      8
# 200    Number of non-anonymous clients who have start...        Count      9
# 205    Number of non-anonymous clients who have start...        Count      9
# ...                                                  ...          ...    ...
# 10975  Number of non-anonymous clients who have start...        Count   4594
# 10976  Number of non-anonymous clients who have start...        Count   7473
# 10977  Number of non-anonymous clients who have start...        Count   7541
# 10978  Number of non-anonymous clients who have start...        Count   7450
# 10979  Number of non-anonymous clients who have start...        Count  27058
# 11005  Number of non-anonymous clients who have start...        Count   6855
# 11006  Number of non-anonymous clients who have start...        Count  10705
# 11007  Number of non-anonymous clients who have start...        Count  10268
# 11008  Number of non-anonymous clients who have start...        Count   9932
# 11009  Number of non-anonymous clients who have start...        Count  37760
# 11010  Number of non-anonymous clients who have start...        Count   6008
# 11011  Number of non-anonymous clients who have start...        Count  10454
# 11012  Number of non-anonymous clients who have start...        Count  10486
# 11013  Number of non-anonymous clients who have start...        Count  10924
# 11014  Number of non-anonymous clients who have start...        Count  37872
# 11015  Number of non-anonymous clients who have start...        Count   6012
# 11016  Number of non-anonymous clients who have start...        Count  10653
# 11017  Number of non-anonymous clients who have start...        Count  10324
# 11018  Number of non-anonymous clients who have start...        Count  11260
# 11019  Number of non-anonymous clients who have start...        Count  38249
# 11020  Number of non-anonymous clients who have start...        Count   6586
# 11021  Number of non-anonymous clients who have start...        Count  10752
# 11022  Number of non-anonymous clients who have start...        Count  10650
# 11023  Number of non-anonymous clients who have start...        Count  10853
# 11024  Number of non-anonymous clients who have start...        Count  38841
# 11025  Number of non-anonymous clients who have start...        Count   6825
# 11026  Number of non-anonymous clients who have start...        Count  10757
# 11027  Number of non-anonymous clients who have start...        Count  10755
# 11028  Number of non-anonymous clients who have start...        Count  10704
# 11029  Number of non-anonymous clients who have start...        Count  39041
#
#                    Unit
# 61     non-anon-clients
# 65     non-anon-clients
# 73     non-anon-clients
# 77     non-anon-clients
# 80     non-anon-clients
# 83     non-anon-clients
# 89     non-anon-clients
# 92     non-anon-clients
# 95     non-anon-clients
# 99     non-anon-clients
# 103    non-anon-clients
# 113    non-anon-clients
# 121    non-anon-clients
# 129    non-anon-clients
# 133    non-anon-clients
# 137    non-anon-clients
# 145    non-anon-clients
# 149    non-anon-clients
# 152    non-anon-clients
# 155    non-anon-clients
# 163    non-anon-clients
# 173    non-anon-clients
# 177    non-anon-clients
# 181    non-anon-clients
# 185    non-anon-clients
# 187    non-anon-clients
# 191    non-anon-clients
# 195    non-anon-clients
# 200    non-anon-clients
# 205    non-anon-clients
# ...                 ...
# 10975  non-anon-clients
# 10976  non-anon-clients
# 10977  non-anon-clients
# 10978  non-anon-clients
# 10979  non-anon-clients
# 11005  non-anon-clients
# 11006  non-anon-clients
# 11007  non-anon-clients
# 11008  non-anon-clients
# 11009  non-anon-clients
# 11010  non-anon-clients
# 11011  non-anon-clients
# 11012  non-anon-clients
# 11013  non-anon-clients
# 11014  non-anon-clients
# 11015  non-anon-clients
# 11016  non-anon-clients
# 11017  non-anon-clients
# 11018  non-anon-clients
# 11019  non-anon-clients
# 11020  non-anon-clients
# 11021  non-anon-clients
# 11022  non-anon-clients
# 11023  non-anon-clients
# 11024  non-anon-clients
# 11025  non-anon-clients
# 11026  non-anon-clients
# 11027  non-anon-clients
# 11028  non-anon-clients
# 11029  non-anon-clients
#
# [9967 rows x 9 columns]
